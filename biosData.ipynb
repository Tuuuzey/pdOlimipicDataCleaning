# %%
import pandas as pd

bios = pd.read_csv('./bios.csv')

# %%
bios.dropna(subset=['died_date'], inplace=True)
bios['died_date'] = pd.to_datetime(bios['died_date'])
bios.sort_values(by='died_date', ascending=False)
# Out:
#        athlete_id                    name   born_date     born_city  \
# 26301       26495  Shahar-ud-Din Abdullah  1948-09-29           NaN
# 71589       72131           Armando Sardi  1940-09-15         Monza
# 37924       38225           Martin Feeley  1950-08-13           NaN
# 72812       73366      Tambusamy Krishnan  1944-07-08        Penang
# 7684         7725           Janusz Gortat  1948-11-05       Brzozów
# ...           ...                     ...         ...           ...
# 17780       17901          Joseph Olivier  1874-12-02     Paris VIe
# 79630       80248        Charles Amberger  1882-01-09  Paris XVIIIe
# 61088       61530        Selwin Calverley  1855-07-04         Leeds
# 21605       21757         Edmond Brassart  1870-03-05      Paris Ve
# 62432       62895         Édouard Mantois  1848-08-23         Blois
#
#            born_region born_country            NOC  height_cm  weight_kg  \
# 26301              NaN          NaN       Malaysia        NaN        NaN
# ...

# %%
bios[['FirstName', 'LastName']] = bios['name'].str.split(n=1, expand=True)
bios
# Out:
#         athlete_id                   name   born_date           born_city  \
# 0                1  Jean-François Blanchy  1886-12-12            Bordeaux
# 2                3           Jean Borotra  1898-08-13            Biarritz
# 3                4        Jacques Brugnon  1895-05-11         Paris VIIIe
# 4                5           Albert Canet  1878-04-17          Wandsworth
# 7                8           Henri Cochet  1901-12-14        Villeurbanne
# ...            ...                    ...         ...                 ...
# 145435      149158      Patrick Gasienica  1998-11-28             McHenry
# 145492      149219  Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
# 145494      149221          George Wright  1890-07-21             Toronto
# 145498      149225         André Foussard  1899-05-19               Niort
# 145499      149814          Bill Phillips  1913-07-15        Dulwich Hill
#
#                  born_region born_country            NOC  height_cm  \
# ...

# %%
bios[(bios['NOC'] == 'Poland') & (bios['FirstName'] == 'Robert')]
# Out:
#        athlete_id               name   born_date          born_city  \
# 10460       10516  Robert Ruszkowski  1942-06-09  Warszawa (Warsaw)
# 52517       52891  Robert Malinowski  1957-03-01  Warszawa (Warsaw)
# 85460       86141   Robert Góralczyk  1943-03-21               Wyry
#
#        born_region born_country     NOC  height_cm  weight_kg  died_date  \
# 10460  Mazowieckie          POL  Poland      187.0       80.0 1998-07-16
# 52517  Mazowieckie          POL  Poland      195.0       87.0 2021-12-08
# 85460      Śląskie          POL  Poland      169.0       72.0 1984-05-18
#
#       FirstName    LastName
# 10460    Robert  Ruszkowski
# 52517    Robert  Malinowski
# 85460    Robert   Góralczyk

# %%
bios.loc[1:5]
# Out:
#    athlete_id             name   born_date    born_city           born_region  \
# 2           3     Jean Borotra  1898-08-13     Biarritz  Pyrénées-Atlantiques
# 3           4  Jacques Brugnon  1895-05-11  Paris VIIIe                 Paris
# 4           5     Albert Canet  1878-04-17   Wandsworth               England
#
#   born_country     NOC  height_cm  weight_kg  died_date FirstName LastName
# 2          FRA  France      183.0       76.0 1994-07-17      Jean  Borotra
# 3          FRA  France      168.0       64.0 1978-03-20   Jacques  Brugnon
# 4          GBR  France        NaN        NaN 1930-07-25    Albert    Canet
